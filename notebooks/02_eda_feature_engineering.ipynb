# %% [markdown]
# # EDA & Feature Engineering
#
# Ce notebook sert de support narratif pour commenter les visuels exploratoires et les variables dérivées.

# %%
from pathlib import Path
from IPython.display import Image, display

root = Path('..').resolve()
for figure_name in [
    'eda_churn_distribution.png',
    'eda_correlation_heatmap.png',
    'eda_transaction_intensity_scatter.png',
]:
    display(Image(filename=root / 'reports' / 'figures' / figure_name))
